# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import config as c
import utils as u



sns.set_context("talk")

# %%
tdf = u.load_trials_df()
tdf = u.compute_days_relative_to_stage(tdf, 5)
# Out:
# Loading days data from directory: /Users/jessbreda/Desktop/github/jbreda_animal_training/notebooks/fixation_publication

# %% [markdown]
# ## Legacy

# %%
V1_ANIMAL = "R042"
df = tdf.query("animal_id == @V1_ANIMAL and stage >=5").copy()
df["total_trials"] = range(len(df))
df =df.query("days_relative_to_stage_5 < 4")

fig, ax = plt.subplots(figsize=(8, 5), dpi=300)
sns.lineplot(
    data=df,
    x="total_trials",
    y="fixation_dur",
    color="white",
    marker=".",
    markeredgecolor="none",
)

# Find the unique session start points
session_starts = df.groupby("sess_id")["total_trials"].min() - 1

# # Plot a vertical line at the start of each new session
# for session_start in session_starts:
#     if session_start > 0:
#         ax.axvline(x=session_start, color="gray", linestyle="--", lw=2)

ax.set(xlabel="Trial Number", title="", ylim=(-0.1, 1.2), xlim=(0, 2100))
ax.axhline(0.8, color="black")
ax.set_ylabel("")

sns.despine(ax=ax)

# %%
V1_ANIMAL = "R042"
df = tdf.query("animal_id == @V1_ANIMAL and stage >=5").copy()
df["total_trials"] = range(len(df))
df =df.query("days_relative_to_stage_5 < 4")

fig, ax = plt.subplots(figsize=(8, 5), dpi=300)
sns.lineplot(
    data=df.query("total_trials < 580"),
    x="total_trials",
    y="fixation_dur",
    color=c.V1_COLOR,
    marker=".",
    markeredgecolor="none",
)

# Find the unique session start points
session_starts = df.groupby("sess_id")["total_trials"].min() - 1

# Plot a vertical line at the start of each new session
for session_start in session_starts:
    print(session_start)
    if session_start > 0 and session_start < 580:
        ax.axvline(x=session_start, color="gray", linestyle="--", lw=2)

ax.set(xlabel="Trial Number", title="", ylim=(-0.1, 1.2), xlim=(0, 2100))
ax.axhline(0.8, color="black")
ax.set_ylabel("")

sns.despine(ax=ax)
# Out:
# -1
# 579
# 1035
# 1532

# %%
V1_ANIMAL = "R042"
df = tdf.query("animal_id == @V1_ANIMAL and stage >=5").copy()
df["total_trials"] = range(len(df))
df =df.query("days_relative_to_stage_5 < 4")

fig, ax = plt.subplots(figsize=(8, 5), dpi=300)
sns.lineplot(
    data=df.query("total_trials < 1030"),
    x="total_trials",
    y="fixation_dur",
    color=c.V1_COLOR,
    marker=".",
    markeredgecolor="none",
)

# Find the unique session start points
session_starts = df.groupby("sess_id")["total_trials"].min() - 1

# Plot a vertical line at the start of each new session
for session_start in session_starts:
    if session_start > 0 and session_start < 1250:
        ax.axvline(x=session_start, color="gray", linestyle="--", lw=2)

ax.set(xlabel="Trial Number", title="", ylim=(-0.1, 1.2), xlim=(0, 2100))
ax.axhline(0.8, color="black")
ax.set_ylabel("")

sns.despine(ax=ax)

# %%
V1_ANIMAL = "R042"
df = tdf.query("animal_id == @V1_ANIMAL and stage >=5").copy()
df["total_trials"] = range(len(df))
df =df.query("days_relative_to_stage_5 < 4")

fig, ax = plt.subplots(figsize=(8, 5), dpi=300)
sns.lineplot(
    data=df,
    x="total_trials",
    y="fixation_dur",
    color=c.V1_COLOR,
    marker=".",
    markeredgecolor="none",
)

# Find the unique session start points
session_starts = df.groupby("sess_id")["total_trials"].min() - 1

# Plot a vertical line at the start of each new session
for session_start in session_starts:
    if session_start > 0:
        ax.axvline(x=session_start, color="gray", linestyle="--", lw=2)

ax.set(xlabel="Trial Number", title="", ylim=(-0.1, 1.2), xlim=(0, 2100))
ax.axhline(0.8, color="black")
ax.set_ylabel("")

sns.despine(ax=ax)

# %% [markdown]
# ## FixGrower

# %%
pdf = u.load_poke_df()
pdf = u.compute_days_relative_to_stage(pdf, 5)
# Out:
# Loading poke data from directory: /Users/jessbreda/Desktop/github/jbreda_animal_training/notebooks/fixation_publication

# %%
V2_ANIMAL = "R043"
df = pdf.query("animal_id == @V2_ANIMAL and stage >=5").copy().sort_values(by="days_relative_to_stage_5", ascending=True)
df["total_trials"] = range(len(df))
df =df.query("days_relative_to_stage_5< 4")

# %%
fig, ax = plt.subplots(figsize=(8, 5), dpi=300)
sns.lineplot(
    data=df,
    x="total_trials",
    y="fixation_dur",
    color="white",
    marker=".",
    markeredgecolor="none",
)

# Find the unique session start points
session_starts = df.groupby("sessid")["total_trials"].min() - 1

# Plot a vertical line at the start of each new session
# for session_start in session_starts:
#     if session_start > 0:
#         ax.axvline(x=session_start, color="gray", linestyle="--", lw=2)

ax.set(xlabel="Trial Number", title="", ylim=(-0.1, 1.2), xlim=(0, 2550))
ax.axhline(0.8, color="black")
ax.set_ylabel("", color=c.V2_COLOR)

sns.despine(ax=ax)

# %%
fig, ax = plt.subplots(figsize=(8, 5), dpi=300)
sns.lineplot(
    data=df.query("total_trials < 770"),
    x="total_trials",
    y="fixation_dur",
    color=c.V2_COLOR,
    marker=".",
    markeredgecolor="none",
)

# Find the unique session start points
session_starts = df.groupby("sessid")["total_trials"].min() - 1

# Plot a vertical line at the start of each new session
for session_start in session_starts :
    if session_start > 0 and session_start < 780:
        ax.axvline(x=session_start, color="gray", linestyle="--", lw=2)

ax.set(xlabel="Trial Number", title="", ylim=(-0.1, 1.2), xlim=(0, 2550))
ax.axhline(0.8, color="black")
ax.set_ylabel("", color=c.V2_COLOR)

sns.despine(ax=ax)

# %%
df.columns
# Out:
# Index(['sessid', 'animal_id', 'trial', 'cpoke_dur', 'cpoke_iti',
#        'post_settling_violation', 'settling_violation', 'was_rewarded',
#        'fixation_dur', 'date', 'stage', 'fix_experiment', 'is_first_cpoke',
#        'prev_sma_iti', 'prev_timeout', 'cpoke_iti_adjusted', 'was_valid',
#        'prev_was_valid', 'cpoke_iti_adjusted_summed', 'relative_cpoke_dur',
#        'datetime_col', 'days_relative_to_stage_5', 'total_trials'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(8, 5), dpi=300)
sns.lineplot(
    data=df.query("total_trials < 770"),
    x="total_trials",
    y="fixation_dur",
    color=c.V2_COLOR,
    marker=".",
    markeredgecolor="none",
)

sns.scatterplot(
    data=df.query("total_trials < 770 and was_valid"),
    x="total_trials",
    y="cpoke_dur",
    color=c.VALID_COLOR,
    marker=".",
    edgecolor="none",
    alpha=0.5,
)

# sns.scatterplot(
#     data=df.query("total_trials < 770 and not was_valid"),
#     x="total_trials",
#     y="cpoke_dur",
#     color=c.VIOLATION_COLOR,
#     marker=".",
#     edgecolor="none",
#     alpha=0.5,
# )

# Find the unique session start points
session_starts = df.groupby("sessid")["total_trials"].min() - 1

# Plot a vertical line at the start of each new session
for session_start in session_starts :
    if session_start > 0 and session_start < 780:
        ax.axvline(x=session_start, color="gray", linestyle="--", lw=2)

ax.set(xlabel="Trial Number", title="", ylim=(-0.1, 1.2), xlim=(0, 2550))
ax.axhline(0.8, color="black")
ax.set_ylabel("", color=c.V2_COLOR)

sns.despine(ax=ax)

# %%
fig, ax = plt.subplots(figsize=(8, 5), dpi=300)
sns.lineplot(
    data=df.query("total_trials < 1289"),
    x="total_trials",
    y="fixation_dur",
    color=c.V2_COLOR,
    marker=".",
    markeredgecolor="none",
)

sns.scatterplot(
    data=df.query("total_trials < 770 and was_valid"),
    x="total_trials",
    y="cpoke_dur",
    color=c.VALID_COLOR,
    marker=".",
    edgecolor="none",
    alpha=0.5,
)

# Find the unique session start points
session_starts = df.groupby("sessid")["total_trials"].min() - 1

# Plot a vertical line at the start of each new session
for session_start in session_starts :
    if session_start > 0 and session_start < 1350:
        ax.axvline(x=session_start, color="gray", linestyle="--", lw=2)

ax.set(xlabel="Trial Number", title="", ylim=(-0.1, 1.2), xlim=(0, 2550))
ax.axhline(0.8, color="black")
ax.set_ylabel("")

sns.despine(ax=ax)

# %%
fig, ax = plt.subplots(figsize=(8, 5), dpi=300)
sns.lineplot(
    data=df,
    x="total_trials",
    y="fixation_dur",
    color=c.V2_COLOR,
    marker=".",
    markeredgecolor="none",
)

sns.scatterplot(
    data=df.query("total_trials < 770 and was_valid"),
    x="total_trials",
    y="cpoke_dur",
    color=c.VALID_COLOR,
    marker=".",
    edgecolor="none",
    alpha=0.5,
)

# Find the unique session start points
session_starts = df.groupby("sessid")["total_trials"].min() - 1

# Plot a vertical line at the start of each new session
for session_start in session_starts:
    if session_start > 0:
        ax.axvline(x=session_start, color="gray", linestyle="--", lw=2)

ax.set(xlabel="Trial Number", title="", ylim=(-0.1, 1.2), xlim=(0, 2550))
ax.axhline(0.8, color="black")
ax.set_ylabel("")

sns.despine(ax=ax)
