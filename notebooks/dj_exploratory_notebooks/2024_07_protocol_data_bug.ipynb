# %%
import datajoint as dj

dj.blob.use_32bit_dims = True  # necessary for pd.blob read
bdata = dj.create_virtual_module("bdata", "bdata")
# Out:
# [2024-07-28 12:22:53,246][INFO]: Connecting jbreda@bdata00.pni.princeton.edu:3306
# [2024-07-28 12:22:54,797][INFO]: Connected jbreda@bdata00.pni.princeton.edu:3306

# %% [markdown]
# # Example
#
# Of error I am getting with fetching protocol data struct.
#
# In the protocol data table I am making there is a field called warm_up_imp. It is one trial shorter than all the other fields. It just needs a 0 appended to it at the end. Or, it can be dropped. However, I can't get the pd data at all to change it.

# %%
bad_sessions = [964578, 964576, 964552, 964551]  # R034, R033, R047, R046
date_min = "2024-07-24"
example_animal = "R033"

# %%
subject_session_key = {"ratname": example_animal}
date_min_key = f"sessiondate >= '{date_min}'"

pd = (bdata.Sessions & subject_session_key & date_min_key).fetch(
    "protocol_data", as_dict=True
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 4
#       1 subject_session_key = {"ratname": example_animal}
#       2 date_min_key = f"sessiondate >= '{date_min}'"
# ----> 4 pd = (bdata.Sessions & subject_session_key & date_min_key).fetch(
#       5     "protocol_data", as_dict=True
#       6 )
#
# File ~/anaconda3/envs/behav_viz/lib/python3.10/site-packages/datajoint/fetch.py:231, in Fetch.__call__(self, offset, limit, order_by, format, as_dict, squeeze, download_path, *attrs)
#     229 attributes = [a for a in attrs if not is_key(a)]
#     230 ret = self._expression.proj(*attributes)
# --> 231 ret = ret.fetch(
#     232     offset=offset,
#     233     limit=limit,
#     234     order_by=order_by,
#     235     as_dict=False,
#     236     squeeze=squeeze,
#     237     download_path=download_path,
#     238     format="array",
#     239 )
# ...

# %% [markdown]
# Also doesn't work if not fetching as dict

# %%
pd = (bdata.Sessions & subject_session_key & date_min_key).fetch(
    "protocol_data", as_dict=False
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pd = (bdata.Sessions & subject_session_key & date_min_key).fetch(
#       2     "protocol_data", as_dict=False
#       3 )
#
# File ~/anaconda3/envs/behav_viz/lib/python3.10/site-packages/datajoint/fetch.py:231, in Fetch.__call__(self, offset, limit, order_by, format, as_dict, squeeze, download_path, *attrs)
#     229 attributes = [a for a in attrs if not is_key(a)]
#     230 ret = self._expression.proj(*attributes)
# --> 231 ret = ret.fetch(
#     232     offset=offset,
#     233     limit=limit,
#     234     order_by=order_by,
#     235     as_dict=False,
#     236     squeeze=squeeze,
#     237     download_path=download_path,
#     238     format="array",
#     239 )
#     240 if attrs_as_dict:
#     241     ret = [
#     242         {k: v for k, v in zip(ret.dtype.names, x) if k in attrs}
# ...
