# %%
import numpy as np
import pandas as pd
import datajoint as dj
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context("notebook")

# %%
ALL_ANIMALS = [
    "R500",
    "R501",
    "R502",
    "R503",
    "R600",
    "R610",
    "R611",
    "R612",
    "R613",
    "R614",
    "Y500",
    "Y501",
    "Y502",
    "Y503",
    "Y601",
    "Y510",
    "Y511",
    "Y512",
    "Y513",
    "Y514",
    "W600",
    "W601",
    "W602",
    "W603",
    "W510",
    "W511",
    "W512",
    "W513",
]

# %%
MODE = "online"
if MODE == "online":
    ratinfo = dj.create_virtual_module("intfo", "ratinfo")

    ANIMALS = ALL_ANIMALS

    Mass_keys = [{"ratname": animal} for animal in ANIMALS]
    mass_df = pd.DataFrame((ratinfo.Mass & Mass_keys).fetch(as_dict=True))
    mass_df["mass"] = mass_df["mass"].replace(0, np.nan)
    mass_df.to_csv("mass_Ws.csv", index=False)

if MODE == "offline":
    mass_df = pd.read_csv("mass.csv")

# %%
mass_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4636 entries, 0 to 4635
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mass      4387 non-null   object
#  1   weighing  4636 non-null   int64
#  2   date      4636 non-null   object
#  3   ratname   4636 non-null   object
#  4   tech      4636 non-null   object
#  5   timeval   4636 non-null   timedelta64[ns]
# dtypes: int64(1), object(4), timedelta64[ns](1)
# memory usage: 217.4+ KB

# %% [markdown]
# ### Calculate baseline weight- minimum date

# %%
# Convert the columns to numeric data type if needed
mass_df["mass"] = pd.to_numeric(mass_df["mass"], errors="coerce")

baseline_df = (
    mass_df.groupby("ratname").agg({"date": "min", "mass": "first"}).reset_index()
)
baseline_df.columns = ["ratname", "min_date", "min_date_mass"]

mass_df = pd.merge(mass_df, baseline_df, on="ratname", how="left")
mass_df["min_date_relative"] = (mass_df["mass"] / mass_df["min_date_mass"]).round(2)

mass_df["min_date_diff"] = mass_df.groupby("ratname")["min_date_relative"].diff()

# %% [markdown]
# ## Plot

# %%
# Create the facet grid plot
g = sns.FacetGrid(
    data=mass_df,
    col="ratname",
    col_wrap=3,
    hue="ratname",
    height=4,
    sharex=False,
    aspect=1.3,
)
g.map(sns.lineplot, "date", "min_date_relative")
g.map(plt.axhline, y=0.80, color="red", linestyle="--")
g.set_xticklabels(rotation=45, ha="right")
# g.set_xticklabels()
g.fig.tight_layout()
g.set_axis_labels(y_var="Relative to Baseline")

# plot a vertical line every time there is more than a 10% drop day-to-day
for ax, ratname in zip(g.axes.flat, g.col_names):
    filtered_df = mass_df[mass_df["ratname"] == ratname]
    for _, row in filtered_df[filtered_df["min_date_diff"] < -0.10].iterrows():
        ax.axvline(x=row["date"], color="black")

# %% [markdown]
# Possible ideas:
# * what was the first training day for the above animals?
# * could there be a window of time that's more appropriate than the first day? Ie first 7 masses?

# %%
summary_df = mass_df.groupby("ratname").date.min().reset_index()
summary_df["n_weights"] = summary_df["ratname"].map(
    mass_df.groupby("ratname").mass.count()
)
summary_df["n_weights"] = summary_df["ratname"].map(
    mass_df.groupby("ratname").mass.count()
)
summary_df["min_weight"] = summary_df["ratname"].map(
    mass_df.query("mass > 0").groupby("ratname").mass.min()
)

summary_df["max_weight"] = summary_df["ratname"].map(
    mass_df.groupby("ratname").mass.max()
)

summary_df["min_date_weight"] = summary_df["ratname"].map(
    mass_df.groupby("ratname").min_date_mass.min()
)

summary_df
# Out:
#    ratname        date  n_weights  min_weight  max_weight  min_date_weight
# 0     R500  2022-07-08        252       18.39       28.90            25.23
# 1     R501  2022-07-08        259       20.20       28.60            23.28
# 2     R502  2022-07-08        253       19.69       29.44            22.81
# 3     R503  2022-07-08        253       18.40       28.79            24.53
# 4     R600  2022-07-08        252       16.69       22.62            17.54
# 5     R610  2023-04-06         81       15.32       18.73            17.51
# 6     R611  2023-04-06         80       15.41       17.92            17.62
# 7     R612  2023-04-06         81       14.60       17.46            16.85
# 8     R613  2023-04-06         81       15.23       17.81            17.81
# 9     R614  2023-04-06         81       16.28       19.47            18.53
# 10    W510  2023-04-06         81       16.60       24.35            21.70
# 11    W511  2023-04-06         77       19.70       27.37            22.66
# 12    W512  2023-04-06         81       20.52       24.88            23.96
# 13    W513  2023-04-06         78       21.40       29.03            26.51
# 14    W600  2022-12-08        156       16.61       25.61            21.97
# 15    W601  2022-12-08        156       16.99       26.49            21.21
# 16    W602  2022-12-08        108       16.12       21.50            20.29
# 17    W603  2022-12-08        156       17.29       24.64            20.04
# 18    Y500  2022-07-08        321       18.59       30.00            22.86
# 19    Y501  2022-07-08        319       18.40       28.70            20.82
# 20    Y502  2022-07-08        247       23.25       31.49            25.60
# 21    Y503  2022-07-08        247       21.48       30.89            23.63
# 22    Y510  2023-04-06         81       17.28       25.00            23.21
# 23    Y511  2023-04-06         81       18.11       25.49            25.49
# 24    Y512  2023-04-06         81       20.27       25.95            25.95
# 25    Y513  2023-04-06         81       18.82       25.44            25.44
# 26    Y514  2023-04-06         79       17.60       24.08            22.94
# 27    Y600  2022-07-11         32       16.67       19.73            18.63
# 28    Y601  2022-07-11        252       17.74       25.06            19.33

# %% [markdown]
# ### Assessing male versus female mass differences

# %%
mass_df.head()
# Out:
#    mass  weighing        date ratname tech         timeval    min_date
# 0   NaN   1077880  2022-07-08    R500   FW 0 days 16:49:47  2022-07-08  \
# 1   NaN   1077881  2022-07-08    R501   FW 0 days 16:49:47  2022-07-08
# 2   NaN   1077882  2022-07-08    R502   FW 0 days 16:49:47  2022-07-08
# 3   NaN   1077883  2022-07-08    R503   FW 0 days 16:49:47  2022-07-08
# 4   NaN   1077884  2022-07-08    R600   FW 0 days 16:49:47  2022-07-08
#
#    min_date_mass  min_date_relative  min_date_diff
# 0          25.23                NaN            NaN
# 1          23.28                NaN            NaN
# 2          22.81                NaN            NaN
# 3          24.53                NaN            NaN
# 4          17.54                NaN            NaN

# %%
# if there is a 5 in the name, it's a male, else, female (for now)
mass_df["sex"] = np.where(mass_df["ratname"].str.contains("5"), "male", "female")

# %%
mass_df.groupby("ratname").head()
# Out:
#        mass  weighing        date ratname tech         timeval    min_date
# 0       NaN   1077880  2022-07-08    R500   FW 0 days 16:49:47  2022-07-08  \
# 1       NaN   1077881  2022-07-08    R501   FW 0 days 16:49:47  2022-07-08
# 2       NaN   1077882  2022-07-08    R502   FW 0 days 16:49:47  2022-07-08
# 3       NaN   1077883  2022-07-08    R503   FW 0 days 16:49:47  2022-07-08
# 4       NaN   1077884  2022-07-08    R600   FW 0 days 16:49:47  2022-07-08
# ...     ...       ...         ...     ...  ...             ...         ...
# 3170  21.79   1120618  2023-04-10    Y513   JL 0 days 10:29:46  2023-04-06
# 3171  20.84   1120619  2023-04-10    Y510   JL 0 days 10:31:07  2023-04-06
# 3172  20.01   1120620  2023-04-10    Y514   JL 0 days 10:31:43  2023-04-06
# 3173  21.78   1120622  2023-04-10    Y511   JL 0 days 10:32:32  2023-04-06
# 3174  23.37   1120623  2023-04-10    Y512   JL 0 days 10:33:28  2023-04-06
#
#       min_date_mass  min_date_relative  min_date_diff     sex
# 0             25.23                NaN            NaN    male
# 1             23.28                NaN            NaN    male
# 2             22.81                NaN            NaN    male
# 3             24.53                NaN            NaN    male
# 4             17.54                NaN            NaN  female
# ...             ...                ...            ...     ...
# 3170          25.44               0.86           0.00    male
# 3171          23.21               0.90          -0.01    male
# 3172          22.94               0.87           0.01    male
# 3173          25.49               0.85          -0.02    male
# 3174          25.95               0.90           0.00    male
#
# [145 rows x 11 columns]

# %% [markdown]
# In a boxen plot, the central box represents the interquartile range (IQR), which spans the middle 50% of the data. The height of the box indicates the range of the IQR. The median is typically displayed as a horizontal line within the box.
#
# Additionally, boxen plots divide the data into smaller quantiles, known as "boxes," within the central box. These boxes provide a more granular representation of the distribution, especially for datasets with large sample sizes. The width of each box is proportional to the square root of the number of observations in that group.
#
# Outliers are displayed as individual points beyond the whiskers, which extend from the central box. Unlike traditional box plots, boxen plots show a varying number of whiskers, adapting to the density of the data.

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5), sharey=True)
sns.violinplot(data=mass_df, x="sex", y="mass", ax=ax[0])
sns.boxenplot(data=mass_df, x="sex", y="mass", ax=ax[1])
# Out:
# <Axes: xlabel='sex', ylabel='mass'>

# %% [markdown]
# #### Mass over time

# %%
mass_df = mass_df.sort_values(["ratname", "date"])

mass_df["n_weighings"] = mass_df.groupby(["ratname"]).cumcount()

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
sns.lineplot(data=mass_df, x="n_weighings", y="mass", hue="sex", ax=ax)
ax.set(title="Mass over time", xlabel="Number of weighings", ylabel="Mass (g)")
# Out:
# [Text(0.5, 1.0, 'Mass over time'),
#  Text(0.5, 0, 'Number of weighings'),
#  Text(0, 0.5, 'Mass (g)')]

# %% [markdown]
# #### Mass by animal and sex

# %%
fig, ax = plt.subplots(2, 1, figsize=(15, 10))
for i, (sex, sub_df) in enumerate(mass_df.groupby("sex")):
    sns.boxplot(
        ax=ax[i],
        data=sub_df,
        x="ratname",
        y="mass",
        hue="ratname",
        dodge=False,
    )
    ax[i].axhline(y=sub_df.mass.mean(), color="gray", linestyle="--")
    ax[i].legend().remove()
    ax[i].set(xlabel="", ylabel="mass [g]", title=f"{sex} mass")

# %% [markdown]
# ### Relative Water

# %%
# from create_days_df import create_days_df_from_dj

# days_df = create_days_df_from_dj(animal_ids=ALL_ANIMALS)
# days_df.to_csv("days_df.csv", index=False)
days_df = pd.read_csv("summary_df.csv")
# Out:
# [2023-07-06 17:07:10,695][WARNING]: MySQL server has gone away. Reconnecting to the server.

# %%
days_df["sex"] = np.where(days_df["animal_id"].str.contains("5"), "male", "female")
days_df["mass"] = days_df["mass"].replace(0, np.nan)

# %%
days_df["volume_drunk"] = days_df["pub_volume"] + days_df["rig_volume"]
days_df["percent_bw_drunk"] = (days_df["volume_drunk"] / days_df["mass"]) * 100
days_df["n_weighings"] = days_df.groupby(["animal_id"]).cumcount()

# %%
days_df_water = days_df.copy()
days_df_water = days_df_water.query("rig_volume > 0 & animal_id != 'Y600'")
days_df_water.reset_index(inplace=True, drop=True)
days_df_water["n_sess"] = days_df_water.groupby(["animal_id"]).cumcount()

# %%
fig, ax = plt.subplots(2, 1, figsize=(15, 10), sharey=True)

for i, (sex, sub_df) in enumerate(days_df_water.groupby("sex")):
    sns.boxplot(
        ax=ax[i],
        data=sub_df,
        x="animal_id",
        y="volume_target",
        hue="animal_id",
        dodge=False,
    )
    ax[i].axhline(y=1, color="black", linestyle="--")
    ax[i].axhline(y=sub_df.volume_target.mean(), color="gray", linestyle="--")
    ax[i].legend().remove()
    ax[i].set(xlabel="", ylabel="Water Target [mL]", title=f"{sex} water target volume")

# %%
fig, ax = plt.subplots(2, 1, figsize=(15, 10), sharey=True)

for i, (sex, sub_df) in enumerate(days_df_water.groupby("sex")):
    sns.boxplot(
        ax=ax[i],
        data=sub_df,
        x="animal_id",
        y="volume_drunk",
        hue="animal_id",
        dodge=False,
    )
    ax[i].axhline(y=1, color="black", linestyle="--")
    ax[i].axhline(y=sub_df.volume_drunk.mean(), color="gray", linestyle="--")
    ax[i].legend().remove()
    ax[i].set(xlabel="", ylabel="Water Target [mL]", title=f"{sex} water drunk")
    y_ticks = np.arange(0, 3, 0.2)
    ax[i].set_yticks(y_ticks)
    ax[i].set_yticklabels([f"{tick:.1f}" for tick in y_ticks])

# %%
fig, ax = plt.subplots(2, 1, figsize=(15, 10))

for i, (sex, sub_df) in enumerate(days_df_water.groupby("sex")):
    sns.boxplot(
        ax=ax[i],
        data=sub_df,
        x="animal_id",
        y="percent_bw_drunk",
        hue="animal_id",
        dodge=False,
    )
    ax[i].axhline(y=4, color="black", linestyle="--")
    ax[i].axhline(y=sub_df.percent_bw_drunk.mean(), color="gray", linestyle="--")
    ax[i].legend().remove()
    ax[i].set(
        xlabel="", ylabel="Percent of BW Drunk [%]", title=f"{sex} Percent of BW Drunk"
    )

# %%
fig, ax = plt.subplots(2, 1, figsize=(15, 10))
sns.lineplot(
    data=days_df_water.query("sex == 'female'"),
    x="n_weighings",
    y="percent_bw_drunk",
    hue="animal_id",
    legend=False,
    ax=ax[0],
)

sns.lineplot(
    data=days_df_water.query("sex == 'female'"),
    x="n_weighings",
    y="percent_bw_drunk",
    legend=False,
    ax=ax[0],
    color="black",
)


sns.lineplot(
    data=days_df_water.query("sex == 'male'"),
    x="n_weighings",
    y="percent_bw_drunk",
    hue="animal_id",
    legend=False,
    ax=ax[1],
)

sns.lineplot(
    data=days_df_water.query("sex == 'male'"),
    x="n_weighings",
    y="percent_bw_drunk",
    legend=False,
    ax=ax[1],
    color="black",
)
_= ax[0].set(title="Females: Percent of BW Drunk over Time")
_ = ax[1].set(title="Males: Percent of BW Drunk over Time")

plt.tight_layout()
