# %% [markdown]
# ## Violation Plots
#
# Notebook for initial visualizations on violation timing distribution for an animal using parsed events history.

# %%
import datajoint as dj
import blob_transformation as bt
import numpy as np
import pylab as plt
from matplotlib import cm
import pandas as pd
from io_utils import *
from performance_plots import *
from trials_table import *
import blob_transformation as bt

dj.blob.use_32bit_dims = True
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ### R500

# %%
animal_id = 'R500'
df500 = fetch_trials_table([animal_id])
fig,ax = plt.subplots(1,1,figsize=(6,4))
plot_viol_hist(df, ax, title=animal_id)
# Out:
# [2022-11-23 14:22:30,762][INFO]: Connecting jbreda@bdata00.pni.princeton.edu:3306
# [2022-11-23 14:22:30,963][INFO]: Connected jbreda@bdata00.pni.princeton.edu:3306
# dropping 0 sessions of 119
# dropping 0 sessions of 119
# fetched 119 sessions for R500 with latest date 2022-11-23

# %% [markdown]
# ### R501

# %%
animal_id = 'R501'
df501 = fetch_trials_table([animal_id])
fig,ax = plt.subplots(1,1,figsize=(6,4))
plot_viol_hist(df, ax, title=animal_id)
# Out:
# dropping 0 sessions of 122
# dropping 1 sessions of 122
# fetched 121 sessions for R501 with latest date 2022-11-23

# %% [markdown]
# ### R502

# %%
animal_id = 'R502'
df502 = fetch_trials_table([animal_id])
fig,ax = plt.subplots(1,1,figsize=(6,4))
plot_viol_hist(df, ax, title=animal_id)
# Out:
# dropping 1 sessions of 125
# dropping 0 sessions of 124
# fetched 124 sessions for R502 with latest date 2022-11-23

# %% [markdown]
# ### R503

# %%
animal_id = 'R503'
df503 = fetch_trials_table([animal_id])
fig,ax = plt.subplots(1,1,figsize=(6,4))
plot_viol_hist(df, ax, title=animal_id)
# Out:
# dropping 1 sessions of 123
# dropping 1 sessions of 122
# fetched 121 sessions for R503 with latest date 2022-11-23

# %% [markdown]
# ### R600

# %%
animal_id = 'R600'
df600 = fetch_trials_table([animal_id])
fig,ax = plt.subplots(1,1,figsize=(6,4))
plot_viol_hist(df, ax, title=animal_id)
# Out:
# dropping 1 sessions of 123
# dropping 1 sessions of 122
# fetched 121 sessions for R600 with latest date 2022-11-23

# %%
df = fetch_trials_table()
# Out:
# dropping 0 sessions of 119
# dropping 0 sessions of 119
# fetched 119 sessions for R500 with latest date 2022-11-23
# dropping 1 sessions of 125
# dropping 0 sessions of 124
# fetched 124 sessions for R502 with latest date 2022-11-23
# dropping 1 sessions of 123
# dropping 1 sessions of 122
# fetched 121 sessions for R503 with latest date 2022-11-23
# dropping 1 sessions of 123
# dropping 1 sessions of 122
# fetched 121 sessions for R600 with latest date 2022-11-23

# %%
df.to_csv('data/pd_peh_df.csv', index=False)
