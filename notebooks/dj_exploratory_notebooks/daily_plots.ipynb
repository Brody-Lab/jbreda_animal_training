# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from performance_plots import *
import datetime as dt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('full_df.csv', index_col=False)
animal_id = 'R500'
df = df.query("animal_id == 'R500'")
df.date = pd.to_datetime(df.date)
date = pd.Timestamp(2022,11,15) 
df_day =  df[(df['date'] == date)]

# %%
fig, ax = plt.subplots(1,1, figsize=(6,4))

single_date_perf_barplot(df=df, date="2022-11-14", plot_type="hits", ax=ax)

# %%
fig, ax = plt.subplots(1,1, figsize=(6,3))
gg = plot_bias_history(df, ax, latest_date="2022-10-3")

# %%
fig, ax = plt.subplots(figsize = (4,4))
plot_stim_in_use(df_day, ax)
