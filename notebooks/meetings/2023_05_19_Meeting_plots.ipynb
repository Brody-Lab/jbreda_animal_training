# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append('/Users/jessbreda/Desktop/github/jbreda_animal_training/code/training_performance')   

from DMS2_multiday_plots_utils import *
from DMS2_fetch_protocol_data import fetch_latest_trials_data
from dj_utils import return_date_window
# settings
# %load_ext autoreload
# %autoreload 2

sns.set_context("talk")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def create_figure(figsize=(10, 3)):
    fig, ax = plt.subplots(figsize=figsize)
    return fig, ax

# %%
date_min, date_max = return_date_window(latest_date=None, n_days_back=20)

# %%
df = fetch_latest_trials_data(
    animal_ids=None, 
    date_min=date_min, 
    date_max=date_max
)
# Out:
# fetched 20 sessions for R610 between 2023-05-01 and 2023-05-20
# fetched 20 sessions for R611 between 2023-05-01 and 2023-05-20
# fetched 20 sessions for R612 between 2023-05-01 and 2023-05-20
# fetched 20 sessions for R613 between 2023-05-01 and 2023-05-20
# fetched 20 sessions for R614 between 2023-05-01 and 2023-05-20

# %%
fig, ax = plt.subplots(5,1, figsize=(10,12), constrained_layout=True,sharex=True, sharey=True)
for ii, (animal_id, sub_df) in enumerate(df.groupby("animal_id")):
    legend = True if ii > 3 else False
    plot_multiday_perfs(sub_df, ax[ii], title=animal_id, legend=legend)

# %%
fig, ax = plt.subplots(5,1, figsize=(10,12), constrained_layout=True,sharex=True, sharey=True)
for ii, (animal_id, sub_df) in enumerate(df.groupby("animal_id")):
    legend = True if ii > 3 else False
    plot_multiday_delay_params(sub_df, ax[ii], title=animal_id, legend=legend)
