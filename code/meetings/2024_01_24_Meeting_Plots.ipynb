# %%
import sys
sys.path.append('../training_performance')

import platform
from pathlib import Path
from datetime import datetime, timedelta
import datajoint as dj
dj.blob.use_32bit_dims = True # necessary for pd.blob read

from create_trials_df import create_trials_df_from_dj
from create_days_df import create_days_df_from_dj, lazy_load_days_summary_df

from multiplot_summaries import *

import plot_utils as pu
import dj_utils as dju
import dir_utils as du

from plot_trials_info import *
from plot_days_info import *

import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np 

# settings
# %load_ext autoreload
# %autoreload 2
sns.set_context("talk")
# Out:
# [2024-01-25 14:47:22,263][INFO]: Connecting jbreda@bdata00.pni.princeton.edu:3306
# [2024-01-25 14:47:22,657][INFO]: Connected jbreda@bdata00.pni.princeton.edu:3306

# %%
cohort3 = [
    "R030",
    "R031",
    "R032",
    "R033",
    "R034",
    "R035",
    "R036",
    "R037",
    "R038",
    "R039",
]

c3df = create_trials_df_from_dj(
    cohort3,
)
# Out:
# fetched 20 sessions for R030 between 2024-01-03 and 2024-01-24
# fetched 21 sessions for R031 between 2024-01-03 and 2024-01-24
# Not all variables are the same length. Cannot create proper DataFrame
# result: 148
# hits: 148
# violations: 148
# temperror: 148
# hit_rate: 147
# error_rate: 147
# violation_rate: 147
# temp_error_rate: 147
# n_lpokes: 147
# n_cpokes: 147
# n_rpokes: 147
# trial_dur: 147
# trial_start: 147
# valid_early_spoke: 147
# first_spoke: 147
# first_lpoke: 147
# first_rpoke: 147
# n_settling_ins: 147
# avg_settling_in: 147
# cpoke_dur: 147
# wf_cpoke_dur: 147
# n_incorr_spokes_during_give_del: 147
# stage: 147
# curriculum: 147
# sides: 148
# SMA_set: 147
# is_match: 148
# sa: 147
# sb: 147
# stimuli_on: 147
# settling_in_dur: 147
# legal_cbreak_dur: 147
# pre_dur: 147
# adj_pre_dur: 147
# stimulus_dur: 147
# delay_dur: 147
# post_dur: 147
# sb_extra_dur: 147
# viol_off_dur: 147
# pre_go_dur: 147
# inter_trial_dur: 147
# go_type: 147
# go_dur: 147
# give_type_set: 147
# give_type_imp: 147
# give_frac: 147
# give_delay_dur: 147
# give_xtra_light_delay_dur: 147
# give_use: 148
# replay_on: 147
# timeouts: 148
# water_delivered: 148
# give_water_not_drunk: 148
# crash_hist: 147
# pro_stim_set: 147
# anti_stim_set: 147
# pro_anti_block_type: 147
# block_switch_type: 147
# pro_hit_rate: 147
# anti_hit_rate: 147
# block_switch_sound_on: 147
# block_swtich_sound_type: 147
# block_switch_sound_dur: 147
# stim_set: 147
# was_block_swtich: 147
# n_blocks: 147
# block_size: 147
# pro_anti_on: 147
# give_delay_strict: 147
# pro_prob: 147
# pro_anti_hit_thresh: 147
# pro_anti_viol_thresh: 147
# max_blocks: 147
# volume_multiplier: 147
# l_water_vol: 147
# r_water_vol: 147
# ab_l_prob: 147
# ab_r_prob: 147
# ab_beta: 147
# ab_tau: 147
# exp_del_tau: 147
# exp_del_min: 147
# exp_del_max: 147
# session 943997 df is outside of length tolerance! trials: 148 df: 0!
# fetched 22 sessions for R032 between 2024-01-03 and 2024-01-24
# fetched 21 sessions for R033 between 2024-01-03 and 2024-01-24
# fetched 21 sessions for R034 between 2024-01-03 and 2024-01-24
# fetched 20 sessions for R035 between 2024-01-03 and 2024-01-24
# Not all variables are the same length. Cannot create proper DataFrame
# result: 403
# hits: 403
# violations: 403
# temperror: 403
# hit_rate: 403
# error_rate: 403
# violation_rate: 403
# temp_error_rate: 403
# n_lpokes: 403
# n_cpokes: 403
# n_rpokes: 403
# trial_dur: 403
# trial_start: 403
# valid_early_spoke: 403
# first_spoke: 403
# first_lpoke: 403
# first_rpoke: 403
# n_settling_ins: 403
# avg_settling_in: 403
# cpoke_dur: 403
# wf_cpoke_dur: 0
# n_incorr_spokes_during_give_del: 403
# stage: 403
# curriculum: 403
# sides: 403
# SMA_set: 403
# is_match: 403
# sa: 403
# sb: 403
# stimuli_on: 403
# settling_in_dur: 403
# legal_cbreak_dur: 403
# pre_dur: 403
# adj_pre_dur: 403
# stimulus_dur: 403
# delay_dur: 403
# post_dur: 403
# sb_extra_dur: 403
# viol_off_dur: 403
# pre_go_dur: 403
# inter_trial_dur: 403
# go_type: 403
# go_dur: 403
# give_type_set: 403
# give_type_imp: 403
# give_frac: 403
# give_delay_dur: 403
# give_xtra_light_delay_dur: 403
# give_use: 403
# replay_on: 403
# timeouts: 403
# water_delivered: 403
# give_water_not_drunk: 403
# crash_hist: 403
# pro_stim_set: 403
# anti_stim_set: 403
# pro_anti_block_type: 403
# block_switch_type: 403
# pro_hit_rate: 403
# anti_hit_rate: 403
# block_switch_sound_on: 403
# block_swtich_sound_type: 403
# block_switch_sound_dur: 403
# stim_set: 403
# was_block_swtich: 403
# n_blocks: 403
# block_size: 403
# pro_anti_on: 403
# give_delay_strict: 403
# pro_prob: 403
# pro_anti_hit_thresh: 403
# pro_anti_viol_thresh: 403
# max_blocks: 403
# volume_multiplier: 403
# l_water_vol: 403
# r_water_vol: 403
# ab_l_prob: 403
# ab_r_prob: 403
# ab_beta: 403
# ab_tau: 403
# exp_del_tau: 403
# exp_del_min: 403
# exp_del_max: 403
# Not all variables are the same length. Cannot create proper DataFrame
# result: 379
# hits: 379
# violations: 379
# temperror: 379
# hit_rate: 379
# error_rate: 379
# violation_rate: 379
# temp_error_rate: 379
# n_lpokes: 379
# n_cpokes: 379
# n_rpokes: 379
# trial_dur: 379
# trial_start: 379
# valid_early_spoke: 379
# first_spoke: 379
# first_lpoke: 379
# first_rpoke: 379
# n_settling_ins: 379
# avg_settling_in: 379
# cpoke_dur: 379
# wf_cpoke_dur: 0
# n_incorr_spokes_during_give_del: 379
# stage: 379
# curriculum: 379
# sides: 379
# SMA_set: 379
# is_match: 379
# sa: 379
# sb: 379
# stimuli_on: 379
# settling_in_dur: 379
# legal_cbreak_dur: 379
# pre_dur: 379
# adj_pre_dur: 379
# stimulus_dur: 379
# delay_dur: 379
# post_dur: 379
# sb_extra_dur: 379
# viol_off_dur: 379
# pre_go_dur: 379
# inter_trial_dur: 379
# go_type: 379
# go_dur: 379
# give_type_set: 379
# give_type_imp: 379
# give_frac: 379
# give_delay_dur: 379
# give_xtra_light_delay_dur: 379
# give_use: 379
# replay_on: 379
# timeouts: 379
# water_delivered: 379
# give_water_not_drunk: 379
# crash_hist: 379
# pro_stim_set: 379
# anti_stim_set: 379
# pro_anti_block_type: 379
# block_switch_type: 379
# pro_hit_rate: 379
# anti_hit_rate: 379
# block_switch_sound_on: 379
# block_swtich_sound_type: 379
# block_switch_sound_dur: 379
# stim_set: 379
# was_block_swtich: 379
# n_blocks: 379
# block_size: 379
# pro_anti_on: 379
# give_delay_strict: 379
# pro_prob: 379
# pro_anti_hit_thresh: 379
# pro_anti_viol_thresh: 379
# max_blocks: 379
# volume_multiplier: 379
# l_water_vol: 379
# r_water_vol: 379
# ab_l_prob: 379
# ab_r_prob: 379
# ab_beta: 379
# ab_tau: 379
# exp_del_tau: 379
# exp_del_min: 379
# exp_del_max: 379
# Not all variables are the same length. Cannot create proper DataFrame
# result: 335
# hits: 335
# violations: 335
# temperror: 335
# hit_rate: 335
# error_rate: 335
# violation_rate: 335
# temp_error_rate: 335
# n_lpokes: 335
# n_cpokes: 335
# n_rpokes: 335
# trial_dur: 335
# trial_start: 335
# valid_early_spoke: 335
# first_spoke: 335
# first_lpoke: 335
# first_rpoke: 335
# n_settling_ins: 335
# avg_settling_in: 335
# cpoke_dur: 335
# wf_cpoke_dur: 0
# n_incorr_spokes_during_give_del: 335
# stage: 335
# curriculum: 335
# sides: 335
# SMA_set: 335
# is_match: 335
# sa: 335
# sb: 335
# stimuli_on: 335
# settling_in_dur: 335
# legal_cbreak_dur: 335
# pre_dur: 335
# adj_pre_dur: 335
# stimulus_dur: 335
# delay_dur: 335
# post_dur: 335
# sb_extra_dur: 335
# viol_off_dur: 335
# pre_go_dur: 335
# inter_trial_dur: 335
# go_type: 335
# go_dur: 335
# give_type_set: 335
# give_type_imp: 335
# give_frac: 335
# give_delay_dur: 335
# give_xtra_light_delay_dur: 335
# give_use: 335
# replay_on: 335
# timeouts: 335
# water_delivered: 335
# give_water_not_drunk: 335
# crash_hist: 335
# pro_stim_set: 335
# anti_stim_set: 335
# pro_anti_block_type: 335
# block_switch_type: 335
# pro_hit_rate: 335
# anti_hit_rate: 335
# block_switch_sound_on: 335
# block_swtich_sound_type: 335
# block_switch_sound_dur: 335
# stim_set: 335
# was_block_swtich: 335
# n_blocks: 335
# block_size: 335
# pro_anti_on: 335
# give_delay_strict: 335
# pro_prob: 335
# pro_anti_hit_thresh: 335
# pro_anti_viol_thresh: 335
# max_blocks: 335
# volume_multiplier: 335
# l_water_vol: 335
# r_water_vol: 335
# ab_l_prob: 335
# ab_r_prob: 335
# ab_beta: 335
# ab_tau: 335
# exp_del_tau: 335
# exp_del_min: 335
# exp_del_max: 335
# Not all variables are the same length. Cannot create proper DataFrame
# result: 332
# hits: 332
# violations: 332
# temperror: 332
# hit_rate: 332
# error_rate: 332
# violation_rate: 332
# temp_error_rate: 332
# n_lpokes: 332
# n_cpokes: 332
# n_rpokes: 332
# trial_dur: 332
# trial_start: 332
# valid_early_spoke: 332
# first_spoke: 332
# first_lpoke: 332
# first_rpoke: 332
# n_settling_ins: 332
# avg_settling_in: 332
# cpoke_dur: 332
# wf_cpoke_dur: 0
# n_incorr_spokes_during_give_del: 332
# stage: 332
# curriculum: 332
# sides: 332
# SMA_set: 332
# is_match: 332
# sa: 332
# sb: 332
# stimuli_on: 332
# settling_in_dur: 332
# legal_cbreak_dur: 332
# pre_dur: 332
# adj_pre_dur: 332
# stimulus_dur: 332
# delay_dur: 332
# post_dur: 332
# sb_extra_dur: 332
# viol_off_dur: 332
# pre_go_dur: 332
# inter_trial_dur: 332
# go_type: 332
# go_dur: 332
# give_type_set: 332
# give_type_imp: 332
# give_frac: 332
# give_delay_dur: 332
# give_xtra_light_delay_dur: 332
# give_use: 332
# replay_on: 332
# timeouts: 332
# water_delivered: 332
# give_water_not_drunk: 332
# crash_hist: 332
# pro_stim_set: 332
# anti_stim_set: 332
# pro_anti_block_type: 332
# block_switch_type: 332
# pro_hit_rate: 332
# anti_hit_rate: 332
# block_switch_sound_on: 332
# block_swtich_sound_type: 332
# block_switch_sound_dur: 332
# stim_set: 332
# was_block_swtich: 332
# n_blocks: 332
# block_size: 332
# pro_anti_on: 332
# give_delay_strict: 332
# pro_prob: 332
# pro_anti_hit_thresh: 332
# pro_anti_viol_thresh: 332
# max_blocks: 332
# volume_multiplier: 332
# l_water_vol: 332
# r_water_vol: 332
# ab_l_prob: 332
# ab_r_prob: 332
# ab_beta: 332
# ab_tau: 332
# exp_del_tau: 332
# exp_del_min: 332
# exp_del_max: 332
# session 943522 df is outside of length tolerance! trials: 403 df: 0!
# session 943643 df is outside of length tolerance! trials: 379 df: 0!
# session 943853 df is outside of length tolerance! trials: 334 df: 0!
# session 943984 df is outside of length tolerance! trials: 332 df: 0!
# fetched 21 sessions for R036 between 2024-01-03 and 2024-01-24
# fetched 21 sessions for R037 between 2024-01-03 and 2024-01-24
# Not all variables are the same length. Cannot create proper DataFrame
# result: 146
# hits: 146
# violations: 146
# temperror: 146
# hit_rate: 146
# error_rate: 146
# violation_rate: 146
# temp_error_rate: 146
# n_lpokes: 146
# n_cpokes: 146
# n_rpokes: 146
# trial_dur: 146
# trial_start: 146
# valid_early_spoke: 146
# first_spoke: 146
# first_lpoke: 146
# first_rpoke: 146
# n_settling_ins: 146
# avg_settling_in: 146
# cpoke_dur: 146
# wf_cpoke_dur: 0
# n_incorr_spokes_during_give_del: 146
# stage: 146
# curriculum: 146
# sides: 146
# SMA_set: 146
# is_match: 146
# sa: 146
# sb: 146
# stimuli_on: 146
# settling_in_dur: 146
# legal_cbreak_dur: 146
# pre_dur: 146
# adj_pre_dur: 146
# stimulus_dur: 146
# delay_dur: 146
# post_dur: 146
# sb_extra_dur: 146
# viol_off_dur: 146
# pre_go_dur: 146
# inter_trial_dur: 146
# go_type: 146
# go_dur: 146
# give_type_set: 146
# give_type_imp: 146
# give_frac: 146
# give_delay_dur: 146
# give_xtra_light_delay_dur: 146
# give_use: 146
# replay_on: 146
# timeouts: 146
# water_delivered: 146
# give_water_not_drunk: 146
# crash_hist: 146
# pro_stim_set: 146
# anti_stim_set: 146
# pro_anti_block_type: 146
# block_switch_type: 146
# pro_hit_rate: 146
# anti_hit_rate: 146
# block_switch_sound_on: 146
# block_swtich_sound_type: 146
# block_switch_sound_dur: 146
# stim_set: 146
# was_block_swtich: 146
# n_blocks: 146
# block_size: 146
# pro_anti_on: 146
# give_delay_strict: 146
# pro_prob: 146
# pro_anti_hit_thresh: 146
# pro_anti_viol_thresh: 146
# max_blocks: 146
# volume_multiplier: 146
# l_water_vol: 146
# r_water_vol: 146
# ab_l_prob: 146
# ab_r_prob: 146
# ab_beta: 146
# ab_tau: 146
# exp_del_tau: 146
# exp_del_min: 146
# exp_del_max: 146
# Not all variables are the same length. Cannot create proper DataFrame
# result: 242
# hits: 242
# violations: 242
# temperror: 242
# hit_rate: 242
# error_rate: 242
# violation_rate: 242
# temp_error_rate: 242
# n_lpokes: 242
# n_cpokes: 242
# n_rpokes: 242
# trial_dur: 242
# trial_start: 242
# valid_early_spoke: 242
# first_spoke: 242
# first_lpoke: 242
# first_rpoke: 242
# n_settling_ins: 242
# avg_settling_in: 242
# cpoke_dur: 242
# wf_cpoke_dur: 0
# n_incorr_spokes_during_give_del: 242
# stage: 242
# curriculum: 242
# sides: 242
# SMA_set: 242
# is_match: 242
# sa: 242
# sb: 242
# stimuli_on: 242
# settling_in_dur: 242
# legal_cbreak_dur: 242
# pre_dur: 242
# adj_pre_dur: 242
# stimulus_dur: 242
# delay_dur: 242
# post_dur: 242
# sb_extra_dur: 242
# viol_off_dur: 242
# pre_go_dur: 242
# inter_trial_dur: 242
# go_type: 242
# go_dur: 242
# give_type_set: 242
# give_type_imp: 242
# give_frac: 242
# give_delay_dur: 242
# give_xtra_light_delay_dur: 242
# give_use: 242
# replay_on: 242
# timeouts: 242
# water_delivered: 242
# give_water_not_drunk: 242
# crash_hist: 242
# pro_stim_set: 242
# anti_stim_set: 242
# pro_anti_block_type: 242
# block_switch_type: 242
# pro_hit_rate: 242
# anti_hit_rate: 242
# block_switch_sound_on: 242
# block_swtich_sound_type: 242
# block_switch_sound_dur: 242
# stim_set: 242
# was_block_swtich: 242
# n_blocks: 242
# block_size: 242
# pro_anti_on: 242
# give_delay_strict: 242
# pro_prob: 242
# pro_anti_hit_thresh: 242
# pro_anti_viol_thresh: 242
# max_blocks: 242
# volume_multiplier: 242
# l_water_vol: 242
# r_water_vol: 242
# ab_l_prob: 242
# ab_r_prob: 242
# ab_beta: 242
# ab_tau: 242
# exp_del_tau: 242
# exp_del_min: 242
# exp_del_max: 242
# session 943985 df is outside of length tolerance! trials: 146 df: 0!
# session 944391 df is outside of length tolerance! trials: 241 df: 0!
# fetched 19 sessions for R038 between 2024-01-03 and 2024-01-24
# fetched 20 sessions for R039 between 2024-01-03 and 2024-01-24

# %%
c3df["date"] = pd.to_datetime(c3df["date"], format="%Y-%m-%d")
c3df["start_date"] = c3df.groupby("animal_id")["date"].transform(
    lambda x: (x - x.min()).dt.days
)

fig, ax = plt.subplots(figsize=(12, 6))
for animal_id, sub_df in c3df.groupby("animal_id"):
    plot_stage(
        sub_df,
        ax=ax,
        group="start_date",
        aesthetics=False,
        # color=get_species_color(sub_df.species.iloc[0]),
        alpha=0.5,
        label=None,
    )


# for species, sub_df in trials_df.groupby("species"):
plot_stage(
    c3df,
    ax=ax,
    group="start_date",
    aesthetics=False,
    color="black",
    # label=species,
)

max_stage = int(c3df.stage.max())
ax.grid(alpha=0.5)
_ = ax.set(
    ylabel="Stage #",
    title="Stage Progression",
    ylim=(0, max_stage + 1),
    yticks=range(max_stage + 1),
    xlabel="Days since first session",
    xlim=(-5, 30),
    xticks=np.arange(stop=30, step=5),
)

# %%
violation_df = c3df.query("stage >= 8").copy()

session_avg_violations = (
    violation_df.groupby(["animal_id", "sess_id"]).violations.mean().reset_index()
)

fig, ax = pu.make_fig((8, 4))
sns.boxplot(data=session_avg_violations, x="animal_id", y="violations", ax=ax)
ax.axhline(violation_df.violations.mean(), ls="--", color="black")

# %% [markdown]
# ### Anti light guide animals

# %%
alg = ["R014", "R011", "R027", "C222", "R015", "R029"]

trials_df = create_trials_df_from_dj(alg, date_min="2024-01-05")
# Out:
# fetched 20 sessions for R014 between 2024-01-05 and 2024-01-25
# fetched 20 sessions for R011 between 2024-01-05 and 2024-01-25
# fetched 18 sessions for R027 between 2024-01-05 and 2024-01-25
# fetched 19 sessions for C222 between 2024-01-05 and 2024-01-24
# fetched 20 sessions for R015 between 2024-01-05 and 2024-01-25
# fetched 17 sessions for R029 between 2024-01-05 and 2024-01-25

# %%
fig, ax = plt.subplots(3, 1, figsize=(12, 11), sharex=True)

plot_give_info_days(
    trials_df.query("animal_id == 'R014'"),
    aesthetics=False,
    title="R014",
    ax=ax[0],
)
plot_stim_performance_by_pro_anti(
    trials_df.query("animal_id == 'R014'"),
    ax=ax[1],
    aesthetics=False,
)
plot_stim_performance(
    trials_df.query("animal_id == 'R014'"),
    ax=ax[2],
    aesthetics=True,
)

# %%
fig, ax = plt.subplots(len(alg), 1, figsize=(12, 4 * len(alg)), sharex=True)

for ii, (animal_id, sub_df) in enumerate(trials_df.groupby("animal_id")):
    plot_stim_performance_by_pro_anti(
        sub_df,
        ax=ax[ii],
        aesthetics=False,
        title=animal_id,
    )

# %% [markdown]
# ### Give delay dur

# %%
aniamls = ["R010", "R023"]

trials_df = create_trials_df_from_dj(aniamls, date_min="2024-01-05")
# Out:
# fetched 20 sessions for R010 between 2024-01-05 and 2024-01-25
# fetched 18 sessions for R023 between 2024-01-05 and 2024-01-25

# %%
fig, ax = plt.subplots(4, 1, figsize=(12, 4 * 4))
animal = "R010"
plot_stim_performance_by_pro_anti(
    trials_df.query("animal_id == @animal"), aesthetics=False, ax=ax[0]
)
plot_non_give_stim_performance(
    trials_df.query("animal_id == @animal"), aesthetics=False, ax=ax[1]
)
plot_give_delay_dur_days(trials_df.query("animal_id == @animal"), ax=ax[2])
plot_give_use_rate_days(trials_df.query("animal_id == @animal"), ax[3])

# %%
fig, ax = plt.subplots(4, 1, figsize=(12, 4 * 4))
animal = "R023"
plot_stim_performance_by_pro_anti(
    trials_df.query("animal_id == @animal"), aesthetics=False, ax=ax[0]
)
plot_non_give_stim_performance(
    trials_df.query("animal_id == @animal"), aesthetics=False, ax=ax[1]
)
plot_give_delay_dur_days(trials_df.query("animal_id == @animal"), ax=ax[2])
plot_give_use_rate_days(trials_df.query("animal_id == @animal"), ax[3])

# %% [markdown]
# ### R023 daily plots

# %%
date_min = pd.Timestamp(2024, 1, 21).date()

for idx, (date, sub_df) in enumerate(
    trials_df.query("date > @date_min and animal_id =='R023'").groupby("date")
):
    plot_anti_give_del_metrics(sub_df)
